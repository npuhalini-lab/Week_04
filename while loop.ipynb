# %%
i=0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=3
while i<8: 
    print(i,end=" ")
    i+=2
# Out:
# 3 5 7

# %%
password= ""
while password != "python123":
    password=input("enter the password ?")
print("Access Granted")
# Out:
# enter the password ? 111
# enter the password ? python123
# Access Granted

# %%
import time
battery=10
while battery>0:
    print("Battery level:", battery)
    battery-=1
    time.sleep(1)
print("Battery empty!")
# Out:
# Battery level: 10
# Battery level: 9
# Battery level: 8
# Battery level: 7
# Battery level: 6
# Battery level: 5
# Battery level: 4
# Battery level: 3
# Battery level: 2
# Battery level: 1
# Battery empty!

# %%
age=-1
while age<0:
    age=int(input("Enter a valid age ?"))
print("Thank you")
# Out:
# Enter a valid age ? -24
# Enter a valid age ? -2
# Enter a valid age ? -1
# Enter a valid age ? 56
# Thank you

# %%
choice=""
while choice!="3":
    print("1.Add\n2.View\n3.Exit")
    choice=input("Choose an option:")
print("Goodbye")
# Out:
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 2
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 1
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 4
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 3
# Goodbye
