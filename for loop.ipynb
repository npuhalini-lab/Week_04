# %%
# for loops: print 0 to 4
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#while loops: print 0 to 4
i=0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#the range(start, stop, step)
for i in range(10, 36, 3):
    print(i, end=" ")
# Out:
# 10 13 16 19 22 25 28 31 34

# %%
for i in range(-100, -10, 5):
    print(i, end=" ")
# Out:
# -100 -95 -90 -85 -80 -75 -70 -65 -60 -55 -50 -45 -40 -35 -30 -25 -20 -15

# %%
for i in range(5):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
#even number
for i in range(2, 11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#odd number
for i in range(1, 11, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#looping through a list:
Fruits_List=["apple", "banana", "cherry"]
for fruit in Fruits_List:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
#looping through a dictionary:
student={"name":"senaka", "age":30, "grade":"A"}
for key in student:
    print(key,":",student[key])
# Out:
# name : senaka
# age : 30
# grade : A

# %%
#looping through a dictionary:
student={"name":"senaka", "age":30, "grade":"A"}
for key in student:
    print(key)
# Out:
# name
# age
# grade

# %%
for letter in "python":
    print(letter)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for letter in "python":
    print(letter, end="")
# Out:
# python
